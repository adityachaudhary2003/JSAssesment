# %% [markdown]
# <a href="https://colab.research.google.com/github/adityachaudhary2003/JSAssesment/blob/main/cv1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow


def display_image(image, title, cmap=None):
    plt.figure(figsize=(10, 8))
    plt.imshow(image, cmap=cmap)
    plt.title(title)
    plt.axis('off')
    plt.show()



image = cv2.imread(image_path)


image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
image_lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)




display_image(image_rgb, 'RGB')


display_image(image_gray, 'Grayscale', cmap='gray')


display_image(image_hsv, 'HSV')


display_image(image_lab, 'Lab')


cv2.imwrite('output_image_gray.jpg', image_gray)
cv2.imwrite('output_image_hsv.jpg', image_hsv)
cv2.imwrite('output_image_lab.jpg', image_lab)
# Out:
# True
